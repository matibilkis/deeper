# %%
import os 
import tensorflow as tf
import numpy as np
from misc import Prob, Basics
from nets import RNN
from tqdm import tqdm
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

net = RNN()
name="task2_dset"
data, labels = np.load(name+"/data.npy"), np.load(name+"/label.npy")

stoppings = []
for k in range(4):
    for kk in range(10**k,10**(k+1),10**k):
        stoppings.append(kk)
for j in range(1,4):
    stoppings.append(j*10**4)
    
    
dataset=tf.data.Dataset.from_tensor_slices((data,tf.expand_dims(labels,axis=-1)))
net.compile(optimizer=tf.keras.optimizers.Adam(lr=0.001), loss="mse")
dataset=tf.data.Dataset.from_tensor_slices((data,tf.expand_dims(labels,axis=-1)))
h = net.fit(dataset.batch(3200),epochs=10**4, verbose=1)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Train for 1 steps
# Epoch 1/10000
# 1/1 [==============================] - 2s 2s/step - loss: 0.0777
# Epoch 2/10000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0752
# Epoch 3/10000
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0727
# Epoch 4/10000
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0703
# Epoch 5/10000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0679
# Epoch 6/10000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0656
# Epoch 7/10000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0633
# Epoch 8/10000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0611
# Epoch 9/10000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0589
# Epoch 10/10000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0568
# Epoch 11/10000
# ...

# %%
plt.plot(h.history["loss"])

# %%
basics = Basics(dolinar_layers=2)
ats = basics.ats
def pn1(n,beta,alpha=0.4):
    p=0
    for pm in [-1,1]:
        p+=Prob(pm*alpha, beta,n)
    return p/2

def Q2(b1,n1,b2,alpha=0.4):
    p=0
    for n2 in [0,1]:
        p+=max([Prob(pm*alpha*np.cos(ats[0]), b1,n1)*Prob(pm*alpha*np.sin(ats[0]), b2,n2) for pm in [-1.,1.]])
    p/=pn1(n1,b1)
    return p/2

def Q1(b1,alpha=0.4):
    p=0
    for n1 in [0,1]:
        p+= max([Q2(b1,n1,b2,alpha) for b2 in np.arange(-1,1,.05)])*pn1(n1,b1)
    return p



betas = np.arange(-1,1,.05)
test1=[]
for b in betas:
    test1.append([b,-1.])
b1=-.5
data_test = {}
for nn in [0.,1.]:
    data_test[str(nn)] = []
    for b in betas:
        data_test[str(nn)].append([[b1,-1.],[b,nn]])


plt.figure(figsize=(10,10))
plt.suptitle("epoch: {}".format(10**4), size=20)
ax1=plt.subplot2grid((2,2),(0,0))
ax2=plt.subplot2grid((2,2),(1,0))
ax3=plt.subplot2grid((2,2),(0,1),rowspan=2)

axs = {0:ax1,1:ax2}
c=0
for nn in [0.,1.]:
    preds = net(np.reshape(data_test[str(nn)], (len(data_test[str(nn)]), 2,2)))
    axs[c].plot(betas,np.squeeze(preds[:,1]), alpha=0.7, color="blue", linewidth=5)
    axs[c].plot(betas, [Q2(b1,nn,b) for b in betas], '--', label="Q2", alpha=0.7, linewidth=5, color="red")
    c+=1

    dt = []
for b in betas:
    dt.append([[b,-1.]])

ax3.plot(betas,np.squeeze(net(np.array(dt))), alpha=0.7, color="blue", linewidth=5)
ax3.plot(betas, [Q1(b) for b in betas], '--', label="Q1", alpha=0.7, linewidth=5, color="red")
plt.savefig("taks2_epoch_104.png")

# %%
l=[]
ind=0

d = tf.data.Dataset.from_tensor_slices((data, labels))
d.shuffle(buffer_size=10**4)
# Out:
# <ShuffleDataset shapes: ((2, 2), (2,)), types: (tf.float32, tf.float32)>

# %%
b = d.batch(3200)
len(list(b))
# Out:
# 1

# %%
net(list(b)[0][0])
# Out:
# <tf.Tensor: shape=(3200, 2, 1), dtype=float32, numpy=
# array([[[0.80925304],
#         [0.6943227 ]],
#
#        [[0.80925304],
#         [0.70249045]],
#
#        [[0.80925304],
#         [0.7108886 ]],
#
#        ...,
#
#        [[0.8123878 ],
#         [0.7422416 ]],
#
#        [[0.8123878 ],
#         [0.7467177 ]],
#
#        [[0.8123878 ],
#         [0.7504633 ]]], dtype=float32)>

# %%
np.sort([2,1])
# Out:
# array([1, 2])
